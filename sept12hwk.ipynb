# %%
import pandas as pd

# %% [markdown]
# # ChatGPT Chats
#
#
# https://chatgpt.com/share/f396c3bf-67c6-4d67-a489-fcfd2c665b73
#
#
# https://chatgpt.com/share/528238b4-6495-45ee-95f8-d1c8abfc0ac8

# %% [markdown]
# 1. Pick one of the datasets from the ChatBot session(s) of the TUT demo (or from your own ChatBot session if you wish) and use the code produced through the ChatBot interactions to import the data and confirm that the dataset has missing values

# %%
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)
df_saved = df.copy()
df.isna().sum()
# Out:
# row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# dtype: int64

# %%
df.isna()
# Out:
#      row_n     id   name  gender  species  birthday  personality   song  \
# 0    False  False  False   False    False     False        False  False
# 1    False  False  False   False    False     False        False  False
# 2    False  False  False   False    False     False        False  False
# 3    False  False  False   False    False     False        False  False
# 4    False  False  False   False    False     False        False  False
# ..     ...    ...    ...     ...      ...       ...          ...    ...
# 386  False  False  False   False    False     False        False  False
# 387  False  False  False   False    False     False        False  False
# 388  False  False  False   False    False     False        False  False
# 389  False  False  False   False    False     False        False  False
# 390  False  False  False   False    False     False        False  False
#
#      phrase  full_id    url
# 0     False    False  False
# 1     False    False  False
# ...

# %% [markdown]
# 2. Start a new ChatBot session with an initial prompt introducing the dataset you're using and request help to determine how many columns and rows of data a pandas DataFrame has, and then
#
#     use code provided in your ChatBot session to print out the number of rows and columns of the dataset; and,
#     write your own general definitions of the meaning of "observations" and "variables" based on asking the ChatBot to explain these terms in the context of your dataset

# %%
# Getting the number of rows and columns
rows, columns = df.shape

print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 391
# Number of columns: 11

# %% [markdown]
# # 2.2
#
# Observations are the individual entries or rows, where each row represents a bundle of data (such as a character in Animal Crossing)
#
# Variables are the columns, and each column represents a trait or attribute that could be in the bundle of data (such as the species of the character, or alternatively their personality)

# %% [markdown]
# 3. Ask the ChatBot how you can provide simple summaries of the columns in the dataset and use the suggested code to provide these summaries for your dataset

# %%
# Summary statistics for numerical columns
summary = df.describe()

# Summary statistics for all columns (including categorical)
df.describe(include='all')
# Out:
#              row_n       id     name gender species birthday personality  \
# count   391.000000      390      391    391     391      391         391
# unique         NaN      390      391      2      35      361           8
# top            NaN  admiral  Admiral   male     cat     1-27        lazy
# freq           NaN        1        1    204      23        2          60
# mean    239.902813      NaN      NaN    NaN     NaN      NaN         NaN
# std     140.702672      NaN      NaN    NaN     NaN      NaN         NaN
# min       2.000000      NaN      NaN    NaN     NaN      NaN         NaN
# 25%     117.500000      NaN      NaN    NaN     NaN      NaN         NaN
# 50%     240.000000      NaN      NaN    NaN     NaN      NaN         NaN
# 75%     363.500000      NaN      NaN    NaN     NaN      NaN         NaN
# max     483.000000      NaN      NaN    NaN     NaN      NaN         NaN
#
#                 song   phrase           full_id  \
# ...

# %% [markdown]
# # 4
#
# 4. If the dataset you're using has (a) non-numeric variables and (b) missing values in numeric variables, explain (perhaps using help from a ChatBot if needed) the discrepancies between size of the dataset given by df.shape and what is reported by df.describe() with respect to (a) the number of columns it analyzes and (b) the values it reports in the "count" column

# %% [markdown]
# `df.shape` counts all of the columns, even if data is missing from them, or if they are non-numeric.
#
#
# `df.describe()` only looks at the values that aren't missing, so there will be a discrepancy between df.shape and `df.describe()` if there is data missing from the dataset. `describe` also cannot perform calculations on non-numeric values, as arithmetic operations are not really defined with strings, so they are treated similarly to missing values, in that they aren't accounted for in the calculations.
#
#
# Find missing values in each column

# %%
print(summary)
# Out:
#             row_n
# count  391.000000
# mean   239.902813
# std    140.702672
# min      2.000000
# 25%    117.500000
# 50%    240.000000
# 75%    363.500000
# max    483.000000

# %%
df['species'].value_counts()
df.head()
# Out:
#    row_n       id     name  gender    species birthday personality  \
# 0      2  admiral  Admiral    male       bird     1-27      cranky
# 1      3  agent-s  Agent S  female   squirrel      7-2       peppy
# 2      4    agnes    Agnes  female        pig     4-21        uchi
# 3      6       al       Al    male    gorilla    10-18        lazy
# 4      7  alfonso  Alfonso    male  alligator      6-9        lazy
#
#           song    phrase           full_id  \
# 0   Steep Hill   aye aye  villager-admiral
# 1      DJ K.K.  sidekick  villager-agent-s
# 2   K.K. House   snuffle    villager-agnes
# 3   Steep Hill   Ayyeeee       villager-al
# 4  Forest Life  it'sa me  villager-alfonso
#
#                                                  url
# 0  https://villagerdb.com/images/villagers/thumb/...
# 1  https://villagerdb.com/images/villagers/thumb/...
# 2  https://villagerdb.com/images/villagers/thumb/...
# 3  https://villagerdb.com/images/villagers/thumb/...
# ...

# %%
print("\nMissing values in each column:\n", df.isnull().sum())

# Non-missing values count
print("\nNon-missing values count per column:\n", df.count())

# First 5 rows to inspect the data
df.head()
# Out:
# Missing values in each column:
#  row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# dtype: int64
#
# Non-missing values count per column:
#  row_n          391
# id             390
# name           391
# gender         391
# species        391
# birthday       391
# personality    391
# song           380
# phrase         391
# full_id        391
# url            391
# dtype: int64
#    row_n       id     name  gender    species birthday personality  \
# 0      2  admiral  Admiral    male       bird     1-27      cranky
# 1      3  agent-s  Agent S  female   squirrel      7-2       peppy
# 2      4    agnes    Agnes  female        pig     4-21        uchi
# 3      6       al       Al    male    gorilla    10-18        lazy
# 4      7  alfonso  Alfonso    male  alligator      6-9        lazy
#
# ...

# %% [markdown]
# 5. Use your ChatBot session to help understand the difference between the following and then provide your own paraphrasing summarization of that difference between an attribute and a method

# %% [markdown]
# df.shape, the attribute, provides the dimensions of the dataframe
# it quickly checks the size of the DataFrame
# it is a characteristic or a property that an object has
# df.describe() provides summary statistics, which means that it analyzes numeric columns
# it also works to exclude missing data,
# a method is a behavior or action that the object can do

# %% [markdown]
# df.dropna() removes rows that contain missing values,
# while `del df['col']` removes the entire column from the DataFrame
#
# df.dropna() should be used when rows that contain missing values should be removed, but the rest of the data should be ket
#
# e.g. We are about to perform arithmetic/other calculations on the data, which otherwise cannot be done if data is missing from the table. We can remove the rows with missing values, while keeping the rest for the calculations by doing df.dropna()
#
# On the other hand, `del df['col']` should be used when an entire column's data is deemed unnecessary in order to remove the column from the dataframe. This cam be done whether or not the column actually contains missing values.
#
# e.g. The personality of each villager is no longer of use to us, as perhaps we're only interested in their physical traits. Alternatively, perhaps it contains a lot of missing numbers and using `del df['col']` would mean that too much data will be lost. `del df['personality']` can then be used to remove the unnecessary data.
#
# The two should be used together when there are unnecessary columns present and the remaining data must be cleaned. This means that after the columns that are no longer of interest are removed, those with missing data are also removed next in order to ensure that the data remaining will be more complete.

# %%
del df['birthday']
df.dropna()
# Out:
#      row_n        id      name  gender    species personality  \
# 0        2   admiral   Admiral    male       bird      cranky
# 1        3   agent-s   Agent S  female   squirrel       peppy
# 2        4     agnes     Agnes  female        pig        uchi
# 3        6        al        Al    male    gorilla        lazy
# 4        7   alfonso   Alfonso    male  alligator        lazy
# ..     ...       ...       ...     ...        ...         ...
# 386    475    winnie    Winnie  female      horse       peppy
# 387    477  wolfgang  Wolfgang    male       wolf      cranky
# 388    480      yuka      Yuka  female      koala      snooty
# 389    481      zell      Zell    male       deer        smug
# 390    483    zucker    Zucker    male    octopus        lazy
#
#                 song    phrase            full_id  \
# 0         Steep Hill   aye aye   villager-admiral
# 1            DJ K.K.  sidekick   villager-agent-s
# 2         K.K. House   snuffle     villager-agnes
# ...

# %% [markdown]
# 6. The df.describe() method provides the 'count', 'mean', 'std', 'min', '25%', '50%', '75%', and 'max' summary statistics for each variable it analyzes. Give the definitions (perhaps using help from the ChatBot if needed) of each of these summary statistics

# %% [markdown]
# Count is the number of non-missing entries within a column.
#
# Mean is the average value of the data points present within the column.
#
# The standard deviation (std) measures how dispersed or spread apart the data points are away from the mean.
#
# Min represents the minimum value in that column.
#
# 25% represents Q1, which is the value below which 25% of the data points lie.
#
# 50% represents the median, below which 50% of the data points lie.
#
# 75% represents Q3, below which 75% of the data points lie.
#
# Max is the maximum value found in that column.
#
# These statistics are only comptued with the values that aren't missing, mean that the missing values aren't (because they cannot be) included in the computations.

# %% [markdown]
# 7. Missing data can be considered "across rows" or "down columns". Consider how `df.dropna()` or `del df['col']` should be applied to most efficiently use the available non-missing data in your dataset and briefly answer the following questions in your own words

# %% [markdown]
# `df.dropna()` primarily focuses on rows, and drop all of the rows that comtain missing data. However, if there is a column in particular that contains a lot of missing data, that column should be dropped as removing all of the rows that contain missing data would mean that too much data will be lost.

# %% [markdown]
# # ChatGPT's Summary
# Summary of Interaction:
#
#     Handling Missing Data in Pandas:
#         df.describe(): Provides summary statistics for the DataFrame, ignoring missing values (NaNs). It includes count, mean, std, min, 25%, 50%, 75%, and max as key statistics.
#         df.dropna(): Used to remove rows or columns with missing values, depending on the axis parameter. This helps in cleaning the dataset by excluding incomplete entries.
#         del df['col']: Deletes a specific column from the DataFrame, regardless of whether it has missing values. This is useful for removing irrelevant or unnecessary columns.
#
#     Differences Between Attributes and Methods:
#         Attributes like df.shape represent data or properties of an object (e.g., dimensions of the DataFrame).
#         Methods like df.describe() perform actions or calculations on the object (e.g., calculating summary statistics).
#
#     Handling Missing Data:
#         Discrepancy Between df.shape and df.describe(): Missing data can lead to differences in the count of non-null entries versus total entries.
#         Using df.describe() with Missing Data: Ignores NaNs in calculations, focusing only on non-null values.
#
#     When to Use del df['col'] vs. df.dropna():
#         del df['col']: Used when you need to remove entire columns from the DataFrame.
#         df.dropna(): Used to remove rows or columns with missing values from the DataFrame.
#
#     Combining del df['col'] and df.dropna():
#         Purpose: First remove unnecessary columns and then clean the remaining data by dropping rows or columns with missing values.
#         Importance: Ensures that your DataFrame is both relevant and clean, facilitating more accurate analysis and modeling.

# %% [markdown]
# 8. Give brief explanations in your own words for any requested answers to the questions below

# %%
# import pandas as pd

# URL of the dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'

# Read the dataset into a DataFrame
titanic_df = pd.read_csv(url)

# Display the first few rows of the DataFrame
print(titanic_df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Use your ChatBot session to understand what `df.groupby("col1")["col2"].describe()` does and then demonstrate and explain this using a different example from the "titanic" data set other than what the ChatBot automatically provide for you

# %% [markdown]
# `df.groupby("col1")["col2"].describe()` groups the dataframe using the unique values present in col1, and then goes on to compute summary statistics for col2
# | col1 | col2 |
# |:----------:|:----------:|
# | A   | 1   |
# | A   | 5   |
# | B   | 3   |
# | B   | 4   |
# | B   | 9   |
# | C   | 7   |

# %% [markdown]
# ends up becoming `A -> 1, 5 B -> 3, 4, 9 C -> 7`
#
# Assuming you've not yet removed missing values in the manner of question "7" above, `df.describe()` would have different values in the count value for different data columns depending on the missingness present in the original data. Why do these capture something fundamentally different from the values in the count that result from doing something like `df.groupby("col1")["col2"].describe()`?

# %% [markdown]
# df.describe() would have different values, as it counts the non-missing values for the entire column, regardless of whether it's grouped by col1 or not.
# `df.groupby("col1")["col2"].describe()`'s count is calculated within each group that has been created by `.groupby`, so the value instead represents the number of non-missing for each respective group

# %% [markdown]
# Intentionally introduce the following errors into your code and report your opinion as to whether it's easier to (a) work in a ChatBot session to fix the errors, or (b) use google to search for and fix errors: first share the errors you get in the ChatBot session and see if you can work with ChatBot to troubleshoot and fix the coding errors, and then see if you think a google search for the error provides the necessary toubleshooting help more quickly than ChatGPT

# %% [markdown]
# ChatGPT very quickly identified that pd likely means pandas, and that I likely forgot to `import pandas as pd`. The google search was much more convoluted, as it led to some other related errors that were slightly different, and the top search result was a stackoverflow question which was difficult to navigate.

# %% [markdown]
# Mistype "titanic.csv" as "titanics.csv"
# If ChatBot troubleshooting is based on downloading the file, just replace the whole url with "titanics.csv" and try to troubleshoot the subsequent `FileNotFoundError: [Errno 2] No such file or directory: 'titanics.csv'` (assuming the file is indeed not present)

# %% [markdown]
# ChatGPT did suggest that I check whether I have a typo or not, from which the error could easily be fixed. Adding tyops into other parts of the line sometimes produces errors that are distinct from one another, which is interesting.

# %% [markdown]
# # 8.3
#
# Try to use a dataframe before it's been assigned into the variable
# You can simulate this by just misnaming the variable. For example, if you should write `df.groupby("col1")["col2"].describe()` based on how you loaded the data, then instead write `DF.groupby("col1")["col2"].describe()`

# %%
# DF.groupby("col1")["col2"].describe()

# %% [markdown]
# ChatGPT quickly picked up upon the fact that DF was capitalized, and that I was probably meant to refer to df. The Google search didn't resolve the issue, as capitalization likely isn't considered important in a Google Search. ChatGPT also told me that "Make sure the variable name is correctly defined and matches the case. In Python, variable names are case-sensitive, so DF is different from df. For consistency, it’s better to use lowercase (df is commonly used)". This shows that ChatGPT has a good understanding of how important capitalization of variable names is in Python, and provided me clear guidance as to how to resolve the problem. In this case, ChatGPT was much more useful than Google, as a Google Search wasn't enough to resolve the problem.

# %% [markdown]
# Forget one of the parentheses somewhere the code
# For example, if the code should be pd.read_csv(url) the change it to pd.read_csv(url

# %%
# pd.read_csv(url
# Out:
#   Cell In[19], line 1
#     pd.read_csv(url
#                    ^
# SyntaxError: incomplete input

# %% [markdown]
# ChatGPT instantly recognized that the input was in fact incomplete, and that there should be a closing bracket. The SyntaxError: incomplete input led to a StackOverflow question where the original poster had issues with several nested quotes, resulting in the closing parenthesis being highlighed/counted as a string literal. Google was considerably less useful than ChatGPT

# %% [markdown]
# Use a column name that's not in your data for the `groupby` and column selection
# For example, try capitalizing the columns for example replacing `"sex"` with `"Sex"` in `titanic_df.groupby("sex")["age"].describe()`, and then instead introducing the same error of "age"

# %%
titanic_df.groupby("Sex")["age"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 titanic_df.groupby("Sex")["age"].describe()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# ...

# %% [markdown]
# Google suggested that a more sophisticated error was at play, while ChatGPT realized that S was incorrectly capitalized, and then informed me to check my capitalization as well as column names.

# %% [markdown]
# Forget to put the column name as a string in quotes for the `groupby` and column selection, and see if the ChatBot and google are still as helpful as they were for the previous question
# For example, something like `titanic_df.groupby(sex)["age"].describe()`, and then `titanic_df.groupby("sex")[age].describe()`

# %%
#  titanic_df.groupby(sex)["age"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 titanic_df.groupby(sex)["age"].describe()
#
# NameError: name 'sex' is not defined

# %% [markdown]
# Google was considerably less effective, as it seems like no one else has had this very specific issue before. ChatGPT recognized that sex was being interpreted as a variable instead of as a string literal, and continued to explain how to resolve this error.

# %% [markdown]
# Forget to put the column name as a string in quotes for the `groupby` and column selection, and see if the ChatBot and google are still as helpful as they were for the previous question
# For example, something like `titanic_df.groupby(sex)["age"].describe()`, and then `titanic_df.groupby("sex")[age].describe()`
